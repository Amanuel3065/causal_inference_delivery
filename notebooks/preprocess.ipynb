# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import plotly.express as px
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, Normalizer, StandardScaler, LabelEncoder
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
import sys,os
sys.path.insert(0, '../scripts/')
from data_preProcessing import dataProcessor
from data_exploration import dataExplorer
from data_cleaning import dataCleaner

# %%
#load data
train_df = pd.read_csv("../data/merged.csv")
train_df.head()
# Out:
#    Trip ID          Trip Origin     Trip Destination      Trip Start Time  \
# 0   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 1   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 2   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 3   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 4   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
#
#          Trip End Time  order_id  driver_id driver_action       lat       lng  \
# 0  2021-07-01 09:34:36    392001     243828      accepted  6.602207  3.270465
# 1  2021-07-01 09:34:36    392001     243588      rejected  6.592097  3.287445
# 2  2021-07-01 09:34:36    392001     243830      rejected  6.596133  3.281784
# 3  2021-07-01 09:34:36    392001     243539      rejected  6.596142  3.280526
# 4  2021-07-01 09:34:36    392001     171653      rejected  6.609232  3.288800
#
#    completion_minutes  status trip_st_date  is_holiday  Tr_or_latitude  \
# 0            3.616667       1   2021-07-01       False        6.601042
# 1            3.616667       0   2021-07-01       False        6.601042
# 2            3.616667       0   2021-07-01       False        6.601042
# 3            3.616667       0   2021-07-01       False        6.601042
# 4            3.616667       0   2021-07-01       False        6.601042
#
#    Tr_or_longitude     Distance
# 0         3.276634   694.263614
# 1         3.276634  1551.694105
# 2         3.276634   786.776508
# 3         3.276634   692.053650
# 4         3.276634  1621.848107

# %%
## data info
pp = dataProcessor(train_df)
pp.show_data_information()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1347078 entries, 0 to 1347077
# Data columns (total 17 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Trip ID             1347078 non-null  int64
#  1   Trip Origin         1347078 non-null  object
#  2   Trip Destination    1347078 non-null  object
#  3   Trip Start Time     1347078 non-null  object
#  4   Trip End Time       1347078 non-null  object
#  5   order_id            1347078 non-null  int64
#  6   driver_id           1347078 non-null  int64
#  7   driver_action       1347078 non-null  object
#  8   lat                 1347078 non-null  float64
#  9   lng                 1347078 non-null  float64
#  10  completion_minutes  1347078 non-null  float64
#  11  status              1347078 non-null  int64
#  12  trip_st_date        1347078 non-null  object
#  13  is_holiday          1347078 non-null  bool
#  14  Tr_or_latitude      1347078 non-null  float64
#  15  Tr_or_longitude     1347078 non-null  float64
#  16  Distance            1347078 non-null  float64
# dtypes: bool(1), float64(6), int64(4), object(6)
# memory usage: 165.7+ MB

# %%
train_df.shape
# Out:
# (1347078, 17)

# %%
pp.columns_WithMissingValue()
# Out:
# []

# %%
train_df["driver_action"] = np.where(train_df["driver_action"] == "accepted",1 , 0)

# %%
train_df.head()
# Out:
#    Trip ID          Trip Origin     Trip Destination      Trip Start Time  \
# 0   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 1   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 2   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 3   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 4   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
#
#          Trip End Time  order_id  driver_id  driver_action       lat  \
# 0  2021-07-01 09:34:36    392001     243828              1  6.602207
# 1  2021-07-01 09:34:36    392001     243588              0  6.592097
# 2  2021-07-01 09:34:36    392001     243830              0  6.596133
# 3  2021-07-01 09:34:36    392001     243539              0  6.596142
# 4  2021-07-01 09:34:36    392001     171653              0  6.609232
#
#         lng  completion_minutes  status trip_st_date  is_holiday  \
# 0  3.270465            3.616667       1   2021-07-01       False
# 1  3.287445            3.616667       0   2021-07-01       False
# 2  3.281784            3.616667       0   2021-07-01       False
# 3  3.280526            3.616667       0   2021-07-01       False
# 4  3.288800            3.616667       0   2021-07-01       False
#
#    Tr_or_latitude  Tr_or_longitude     Distance
# 0        6.601042         3.276634   694.263614
# 1        6.601042         3.276634  1551.694105
# 2        6.601042         3.276634   786.776508
# 3        6.601042         3.276634   692.053650
# 4        6.601042         3.276634  1621.848107

# %%
train_df.drop('is_holiday',inplace=True,axis=1)

# %%
train_df.head()
# Out:
#    Trip ID          Trip Origin     Trip Destination      Trip Start Time  \
# 0   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 1   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 2   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 3   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
# 4   392001  6.6010417,3.2766339  6.4501069,3.3916154  2021-07-01 09:30:59
#
#          Trip End Time  order_id  driver_id  driver_action       lat  \
# 0  2021-07-01 09:34:36    392001     243828              1  6.602207
# 1  2021-07-01 09:34:36    392001     243588              0  6.592097
# 2  2021-07-01 09:34:36    392001     243830              0  6.596133
# 3  2021-07-01 09:34:36    392001     243539              0  6.596142
# 4  2021-07-01 09:34:36    392001     171653              0  6.609232
#
#         lng  completion_minutes  status trip_st_date  Tr_or_latitude  \
# 0  3.270465            3.616667       1   2021-07-01        6.601042
# 1  3.287445            3.616667       0   2021-07-01        6.601042
# 2  3.281784            3.616667       0   2021-07-01        6.601042
# 3  3.280526            3.616667       0   2021-07-01        6.601042
# 4  3.288800            3.616667       0   2021-07-01        6.601042
#
#    Tr_or_longitude     Distance
# 0         3.276634   694.263614
# 1         3.276634  1551.694105
# 2         3.276634   786.776508
# 3         3.276634   692.053650
# 4         3.276634  1621.848107

# %%
pp.show_data_information()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1347078 entries, 0 to 1347077
# Data columns (total 16 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Trip ID             1347078 non-null  int64
#  1   Trip Origin         1347078 non-null  object
#  2   Trip Destination    1347078 non-null  object
#  3   Trip Start Time     1347078 non-null  object
#  4   Trip End Time       1347078 non-null  object
#  5   order_id            1347078 non-null  int64
#  6   driver_id           1347078 non-null  int64
#  7   driver_action       1347078 non-null  int64
#  8   lat                 1347078 non-null  float64
#  9   lng                 1347078 non-null  float64
#  10  completion_minutes  1347078 non-null  float64
#  11  status              1347078 non-null  int64
#  12  trip_st_date        1347078 non-null  object
#  13  Tr_or_latitude      1347078 non-null  float64
#  14  Tr_or_longitude     1347078 non-null  float64
#  15  Distance            1347078 non-null  float64
# dtypes: float64(6), int64(5), object(5)
# memory usage: 164.4+ MB

# %% [markdown]
# ## Labeling

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
train_df['Trip Origin'] = le.fit_transform(train_df['Trip Origin'])
train_df['Trip Destination'] = le.fit_transform(train_df['Trip Destination'])

# %%
train_df['Trip Start Time'] = le.fit_transform(train_df['Trip Start Time'])
train_df['Trip End Time'] = le.fit_transform(train_df['Trip End Time'])

# %%
pp.show_data_information()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1347078 entries, 0 to 1347077
# Data columns (total 16 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Trip ID             1347078 non-null  int64
#  1   Trip Origin         1347078 non-null  int64
#  2   Trip Destination    1347078 non-null  int64
#  3   Trip Start Time     1347078 non-null  int64
#  4   Trip End Time       1347078 non-null  int64
#  5   order_id            1347078 non-null  int64
#  6   driver_id           1347078 non-null  int64
#  7   driver_action       1347078 non-null  int64
#  8   lat                 1347078 non-null  float64
#  9   lng                 1347078 non-null  float64
#  10  completion_minutes  1347078 non-null  float64
#  11  status              1347078 non-null  int64
#  12  trip_st_date        1347078 non-null  object
#  13  Tr_or_latitude      1347078 non-null  float64
#  14  Tr_or_longitude     1347078 non-null  float64
#  15  Distance            1347078 non-null  float64
# dtypes: float64(6), int64(9), object(1)
# memory usage: 164.4+ MB

# %% [markdown]
# ## Conversion of types

# %%
#conversion of types
train_df['lat'] = train_df['lat'].astype(int)
train_df['lng'] = train_df['lng'].astype(int)
train_df['completion_minutes'] = train_df['completion_minutes'].astype(int)

# %%
pp.show_data_information()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1347078 entries, 0 to 1347077
# Data columns (total 16 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Trip ID             1347078 non-null  int64
#  1   Trip Origin         1347078 non-null  int64
#  2   Trip Destination    1347078 non-null  int64
#  3   Trip Start Time     1347078 non-null  int64
#  4   Trip End Time       1347078 non-null  int64
#  5   order_id            1347078 non-null  int64
#  6   driver_id           1347078 non-null  int64
#  7   driver_action       1347078 non-null  int64
#  8   lat                 1347078 non-null  int64
#  9   lng                 1347078 non-null  int64
#  10  completion_minutes  1347078 non-null  int64
#  11  status              1347078 non-null  int64
#  12  trip_st_date        1347078 non-null  object
#  13  Tr_or_latitude      1347078 non-null  float64
#  14  Tr_or_longitude     1347078 non-null  float64
#  15  Distance            1347078 non-null  float64
# dtypes: float64(3), int64(12), object(1)
# memory usage: 164.4+ MB

# %% [markdown]
# ## Scaling
